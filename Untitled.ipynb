# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
import itertools

# %%
geo_con_defend_1=np.load('state-depend-con/geo_degree_con_defend12.npy')
geo_con_defend_2=np.load('state-depend-con/geo_degree_con_defend7.npy')
geo_con_defend_3=np.load('state-depend-con/geo_degree_con_defend5.npy')
geo_con_defend_4=np.load('state-depend-con/geo_degree_con_defend3.npy')
geo_con1=np.load('state-depend-con/geo_degree_con_12.npy')
geo_con2=np.load('state-depend-con/geo_degree_con_7.npy')
geo_con3=np.load('state-depend-con/geo_degree_con_5.npy')
geo_con4=np.load('state-depend-con/geo_degree_con_3.npy')

# %%
erdos_con_defend_1=np.load('state-depend-con/erdos_degree_con_defend_30.npy')
erdos_con_defend_2=np.load('state-depend-con/erdos_degree_con_defend_20.npy')
erdos_con_defend_3=np.load('state-depend-con/erdos_degree_con_defend_8.npy')
erdos_con_defend_4=np.load('state-depend-con/erdos_degree_con_defend5.npy')
erdos_con_defend_5=np.load('state-depend-con/erdos_degree_con_defend3.npy')

erdos_con1=np.load('state-depend-con/erdos_degree_con_30.npy')
erdos_con2=np.load('state-depend-con/erdos_degree_con_20.npy')
erdos_con3=np.load('state-depend-con/erdos_degree_con_8.npy')
erdos_con4=np.load('state-depend-con/erdos_degree_con_5.npy')
erdos_con5=np.load('state-depend-con/erdos_degree_con_3.npy')

# %%
geo_label_1=np.load('state-depend-geo_exp/geo_degree_labelled-0.npy')
geo_label_2=np.load('state-depend-geo_exp/geo_degree_labelled-1.npy')
geo_label_3=np.load('state-depend-geo_exp/geo_degree_labelled-2.npy')
geo_label_4=np.load('state-depend-geo_exp/geo_degree_labelled-3.npy')

geo_ff_1=np.load('state-depend-geo_exp/geo_degree_ff-0.npy')
geo_ff_2=np.load('state-depend-geo_exp/geo_degree_ff-1.npy')
geo_ff_3=np.load('state-depend-geo_exp/geo_degree_ff-2.npy')
geo_ff_4=np.load('state-depend-geo_exp/geo_degree_ff-3.npy')

geo_1=np.load('state-depend-geo_exp/geo_degree-0.npy')
geo_2=np.load('state-depend-geo_exp/geo_degree-1.npy')
geo_3=np.load('state-depend-geo_exp/geo_degree-2.npy')
geo_4=np.load('state-depend-geo_exp/geo_degree-3.npy')

# %%
erdos_label_1=np.load('state-depend-erdos_exp/erdos_degree_labelled-0.npy')
erdos_label_2=np.load('state-depend-erdos_exp/erdos_degree_labelled-1.npy')
erdos_label_3=np.load('state-depend-erdos_exp/erdos_degree_labelled-2.npy')
erdos_label_4=np.load('state-depend-erdos_exp/erdos_degree_labelled-3.npy')
erdos_label_5=np.load('state-depend-erdos_exp/erdos_degree_labelled-4.npy')

erdos_ff_1=np.load('state-depend-erdos_exp/erdos_degree_ff-0.npy')
erdos_ff_2=np.load('state-depend-erdos_exp/erdos_degree_ff-1.npy')
erdos_ff_3=np.load('state-depend-erdos_exp/erdos_degree_ff-2.npy')
erdos_ff_4=np.load('state-depend-erdos_exp/erdos_degree_ff-3.npy')
erdos_ff_5=np.load('state-depend-erdos_exp/erdos_degree_ff-4.npy')

erdos_1=np.load('state-depend-erdos_exp/erdos_degree-0.npy')
erdos_2=np.load('state-depend-erdos_exp/erdos_degree-1.npy')
erdos_3=np.load('state-depend-erdos_exp/erdos_degree-2.npy')
erdos_4=np.load('state-depend-erdos_exp/erdos_degree-3.npy')
erdos_5=np.load('state-depend-erdos_exp/erdos_degree-4.npy')

# %%
plt.hist(1000-(geo_con_defend_1+geo_con1[:,-1]),alpha=0.8,label='budget=12')
plt.text(50,140,'110.814')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(1000-(np.mean(geo_con1[:,-1]+geo_con_defend_1)))
plt.hist(1000-geo_label_1[:,0],alpha=0.8,label='budget=|T|*p+1')
plt.text(150,180,'150.147')
plt.title('Number of untouched nodes, random geometric')
plt.legend()
plt.savefig('state-depend-con/geo_10.pdf')
plt.show()

print(1000-(np.mean(geo_label_1[:,0])))
# Out:
# 110.814
# 150.147

# %%
plt.hist(1000-(geo_con_defend_2+geo_con2[:,-1]),alpha=0.8,label='budget=7')
plt.text(0,250,'44.291')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(1000-(np.mean(geo_con2[:,-1]+geo_con_defend_2)))
plt.hist(1000-geo_label_2[:,0],alpha=0.8,label='budget=0.5*|T|*p+1')
plt.text(60,200,'52.705')
plt.title('Number of untouched nodes, random geometric')
plt.legend()
plt.savefig('state-depend-con/geo_6.pdf')
plt.show()
print(1000-(np.mean(geo_label_2[:,0])))
# Out:
# 44.291
# 52.705

# %%
plt.hist(1000-(geo_con_defend_3+geo_con3[:,-1]),alpha=0.8,label='budget=5')
plt.text(60,100,'23.051')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(1000-(np.mean(geo_con3[:,-1]+geo_con_defend_3)))
plt.hist(1000-geo_label_3[:,0],alpha=0.8,label='budget=0.25*|T|*p+1')
plt.text(0,350,'15.754')
plt.title('Number of untouched nodes, random geometric')
plt.legend()
plt.savefig('state-depend-con/geo_5.pdf')
plt.show()

print(1000-(np.mean(geo_label_3[:,0])))
# Out:
# 23.051
# 15.754

# %%
plt.hist(1000-(geo_con_defend_4+geo_con4[:,-1]),alpha=0.8,label='budget=3')
plt.text(20, 200, '8.459')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(1000-(np.mean(geo_con4[:,-1]+geo_con_defend_4)))
plt.hist(1000-geo_label_4[:,0],alpha=0.8,label='budget=0.1*|T|*p+1')
plt.text(0, 550, '4.244')
plt.title('Number of untouched nodes, random geometric')
plt.legend()
plt.savefig('state-depend-con/geo_3.pdf')
plt.show()
print(1000-(np.mean(geo_label_4[:,0])))
# Out:
# 8.459
# 4.244

# %%
b=1000-(erdos_con_defend_1+erdos_con1[:,-1])
a = np.zeros(1000)
for i in range(1000):
    if b[i]>=0:
        a[i]=b[i]
    else:
        a[i]=0

# %%
#plt.hist(1000-(erdos_con_defend_1+erdos_con1[:,-1]),alpha=0.8,label='budget=30')
plt.hist(a,alpha=0.8,label='budget=30')
plt.text(0,100,'10.797')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(np.mean(a))
plt.hist(1000-erdos_label_1[:,0],alpha=0.8,label='budget=2*|T|*p+1')
plt.title('Number of untouched nodes, Erdos-Renyi')
plt.text(35, 150, '38.482')
plt.legend()
plt.savefig('state-depend-con/erdos_30.pdf')
plt.show()
print(1000-(np.mean(erdos_label_1[:,0])))
# Out:
# 10.797
# 38.482

# %%
b=1000-(erdos_con_defend_2+erdos_con2[:,-1])
a = np.zeros(1000)
for i in range(1000):
    if b[i]>=0:
        a[i]=b[i]
    else:
        a[i]=0

c=1000-erdos_label_2[:,0]
d = np.zeros(1000)
for i in range(1000):
    if c[i]>=0:
        d[i]=c[i]
    else:
        d[i]=0

# %%
#plt.hist(1000-(erdos_con_defend_2+erdos_con2[:,-1]),alpha=0.8,label='budget=20')
plt.hist(a,alpha=0.8,label='budget=20')
plt.text(0,800,'0.744')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(np.mean(a))
#print(1000-(np.mean(erdos_con2[:,-1]+erdos_con_defend_2)))
#plt.hist(1000-erdos_label_2[:,0],alpha=0.8,label='budget=|T|*p+1')
plt.hist(d,alpha=0.8,label='budget=|T|*p+1')
plt.title('Number of untouched nodes, Erdos-Renyi')
plt.text(7,100,'1.983')
plt.legend()
plt.savefig('state-depend-con/erdos_20.pdf')
plt.show()
print(np.mean(d))
# Out:
# 0.744
# 1.983

# %%
b=1000-(erdos_con_defend_3+erdos_con3[:,-1])
a = np.zeros(1000)
for i in range(1000):
    if b[i]>=0:
        a[i]=b[i]
    else:
        a[i]=0

c=1000-erdos_label_3[:,0]
d = np.zeros(1000)
for i in range(1000):
    if c[i]>=0:
        d[i]=c[i]
    else:
        d[i]=0

# %%
#plt.hist(1000-(erdos_con_defend_3+erdos_con3[:,-1]),alpha=0.8,label='budget=8')
plt.hist(a,alpha=0.8,label='budget=8')
plt.text(0.5,800,'constant: 0.015')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(np.mean(a))
#plt.hist(1000-erdos_label_3[:,0],alpha=0.8,label='budget=0.5*|T|*p+1')
plt.hist(d,alpha=0.8,label='budget=0.5*|T|*p+1')
plt.title('Number of untouched nodes, Erods-Renyi')
plt.text(1,200,'state-dependant: 0.05')
plt.legend()
plt.savefig('state-depend-con/erdos_6.pdf')
plt.show()
print(np.mean(d))
#print(1000-(np.mean(erdos_label_3[:,0])))
# Out:
# 0.015
# 0.05

# %%
b=1000-(erdos_con_defend_4+erdos_con4[:,-1])
a = np.zeros(1000)
for i in range(1000):
    if b[i]>=0:
        a[i]=b[i]
    else:
        a[i]=0

c=1000-erdos_label_4[:,0]
d = np.zeros(1000)
for i in range(1000):
    if c[i]>=0:
        d[i]=c[i]
    else:
        d[i]=0

# %%
#plt.hist(1000-(erdos_con_defend_4+erdos_con4[:,-1]),alpha=0.8,label='budget=5')
plt.hist(a,alpha=0.8,label='budget=5')
plt.text(0.5,800,'constant: 0.017')
plt.text(0.5,200,'state-dependant: 0.009')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(np.mean(a))
plt.hist(d,alpha=0.8,label='budget=0.25*|T|*p+1')
plt.title('Number of untouched nodes, Erdos-Renyi')
plt.legend()
plt.savefig('state-depend-con/erdos_5.pdf')
plt.show()
print(np.mean(d))
# Out:
# 0.017
# 0.009

# %%
b=1000-(erdos_con_defend_5+erdos_con5[:,-1])
a = np.zeros(1000)
for i in range(1000):
    if b[i]>=0:
        a[i]=b[i]
    else:
        a[i]=0

c=1000-erdos_label_5[:,0]
d = np.zeros(1000)
for i in range(1000):
    if c[i]>=0:
        d[i]=c[i]
    else:
        d[i]=0

# %%
plt.hist(a,alpha=0.8,label='budget=3')
plt.text(0.5,800,'constant: 0.012')
plt.text(0.5,200,'state-dependant: 0.026')
#plt.title('Number of untouched nodes, budget=10')
#plt.show()
print(np.mean(a))
plt.hist(d,alpha=0.8,label='budget=0.1*|T|*p+1')
plt.title('Number of untouched nodes, Erdos-Renyi')
plt.legend()
plt.savefig('state-depend-con/erdos_3.pdf')
plt.show()
print(np.mean(d))
# Out:
# 0.012
# 0.026

# %%
plt.hist(np.sum(geo_ff_1,1))
plt.title('Total budget, budget=|T|*pe+1')
plt.show()
print(np.mean(np.sum(geo_ff_1,1)))
# Out:
# 437.873

# %%
plt.hist(geo_con_defend_1)
plt.title('Total budget, budget=12')
plt.show()
print(np.mean(geo_con_defend_1))
# Out:
# 430.284

# %%
plt.hist(np.sum(geo_ff_2,1))
plt.title('Total budget, budget=0.5*|T|*pe+1')
plt.show()
print(np.mean(np.sum(geo_ff_2,1)))
# Out:
# 351.256

# %%
plt.hist(geo_con_defend_2)
plt.title('Total budget, budget=7')
plt.show()
print(np.mean(geo_con_defend_2))
# Out:
# 340.193

# %%
plt.hist(np.sum(geo_ff_3,1))
plt.title('Total budget, budget=0.25*|T|*pe+1')
plt.show()
print(np.mean(np.sum(geo_ff_3,1)))
# Out:
# 250.961

# %%
plt.hist(geo_con_defend_3)
plt.title('Total budget, budget=5')
plt.show()
print(np.mean(geo_con_defend_3))
# Out:
# 280.35

# %%
plt.hist(np.sum(geo_ff_4,1))
plt.title('Total budget, budget=0.1*|T|*pe+1')
plt.show()
print(np.mean(np.sum(geo_ff_4,1)))
# Out:
# 159.049

# %%
plt.hist(geo_con_defend_4)
plt.title('Total budget, budget=2')
plt.show()
print(np.mean(geo_con_defend_4))
# Out:
# 148.892

# %%
plt.hist(np.sum(erdos_ff_1,1))
plt.title('Total budget, budget=2*|T|*pe+1')
plt.show()
print(np.mean(np.sum(erdos_ff_1,1)))

plt.hist(np.sum(erdos_ff_2,1))
plt.title('Total budget, budget=|T|*pe+1')
plt.show()
print(np.mean(np.sum(erdos_ff_2,1)))
plt.hist(np.sum(erdos_ff_3,1))
plt.title('Total budget, budget=0.5*|T|*pe+1')
plt.show()
print(np.mean(np.sum(erdos_ff_3,1)))
plt.hist(np.sum(erdos_ff_4,1))
plt.title('Total budget, budget=0.25*|T|*pe+1')
plt.show()
print(np.mean(np.sum(erdos_ff_4,1)))
plt.hist(np.sum(erdos_ff_5,1))
plt.title('Total budget, budget=0.1*|T|*pe+1')
plt.show()
print(np.mean(np.sum(erdos_ff_5,1)))
# Out:
# 641.541
# 510.853
# 359.872
# 243.893
# 150.079

# %%
plt.hist(erdos_con_defend_1)
plt.title('Total budget, budget=30')
plt.xlabel('total budget')
plt.show()
print(np.mean(erdos_con_defend_1))
plt.hist(erdos_con_defend_2)
plt.title('Total budget, budget=20')
plt.xlabel('total budget')
plt.show()
print(np.mean(erdos_con_defend_2))
plt.hist(erdos_con_defend_3)
plt.title('Total budget, budget=8')
plt.xlabel('total budget')
plt.show()
print(np.mean(erdos_con_defend_3))
plt.hist(erdos_con_defend_4)
plt.title('Total budget, budget=5')
plt.xlabel('total budget')
plt.show()
print(np.mean(erdos_con_defend_4))
plt.hist(erdos_con_defend_5)
plt.title('Total budget, budget=3')
plt.xlabel('total budget')
plt.show()
print(np.mean(erdos_con_defend_5))
# Out:
# 633.12
# 539.46
# 330.512
# 246.76
# 175.695
